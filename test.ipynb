# %%
# %matplotlib inline
from ipy_setup import setup
setup()

# %% [markdown]
# ####Test
# This is some text
# This is an equation:
# $a = \frac{b}{c}$

# %%
v = np.random.rand(100)

# %%
plt.bar(range(100),v)
plt.show()
